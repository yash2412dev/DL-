# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.datasets import mnist
from tensorflow.keras import backend as K

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
((trainX, trainY), (testX, testY)) = mnist.load_data()

# %%
trainX = trainX.reshape((trainX.shape[0], 28 * 28 * 1))
testX = testX.reshape((testX.shape[0], 28 * 28 * 1))

# %%
trainX = trainX.astype("float32") / 255.0
testX = testX.astype("float32") / 255.0

# %%
lb = LabelBinarizer()
trainY = lb.fit_transform(trainY)
testY = lb.transform(testY)

# %%
model = Sequential()
model.add(Dense(256, input_shape=(784,), activation="sigmoid"))
model.add(Dense(128, activation="sigmoid"))
model.add(Dense(10, activation="softmax"))
# Out:
# 2022-11-27 18:16:04.931917: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
print("[INFO] training network...")
sgd = SGD(0.01)
model.compile(loss="categorical_crossentropy", optimizer=sgd,
metrics=["accuracy"])
H = model.fit(trainX, trainY, validation_data=(testX, testY),
epochs=25, batch_size=128)
# Out:
# [INFO] training network...
# Epoch 1/25
# 469/469 [==============================] - 3s 6ms/step - loss: 1.7637 - accuracy: 0.6367 - val_loss: 1.6432 - val_accuracy: 0.6678
# Epoch 2/25
# 469/469 [==============================] - 2s 5ms/step - loss: 1.5398 - accuracy: 0.6727 - val_loss: 1.4147 - val_accuracy: 0.7178
# Epoch 3/25
# 469/469 [==============================] - 2s 4ms/step - loss: 1.3255 - accuracy: 0.7128 - val_loss: 1.2161 - val_accuracy: 0.7339
# Epoch 4/25
# 469/469 [==============================] - 2s 4ms/step - loss: 1.1506 - accuracy: 0.7419 - val_loss: 1.0629 - val_accuracy: 0.7658
# Epoch 5/25
# 469/469 [==============================] - 2s 4ms/step - loss: 1.0172 - accuracy: 0.7671 - val_loss: 0.9467 - val_accuracy: 0.7823
# Epoch 6/25
# 469/469 [==============================] - 2s 5ms/step - loss: 0.9157 - accuracy: 0.7854 - val_loss: 0.8573 - val_accuracy: 0.8038
# Epoch 7/25
# 469/469 [==============================] - 2s 4ms/step - loss: 0.8360 - accuracy: 0.8014 - val_loss: 0.7859 - val_accuracy: 0.8112
# Epoch 8/25
# 469/469 [==============================] - 2s 5ms/step - loss: 0.7715 - accuracy: 0.8152 - val_loss: 0.7275 - val_accuracy: 0.8243
# Epoch 9/25
# 469/469 [==============================] - 2s 5ms/step - loss: 0.7182 - accuracy: 0.8248 - val_loss: 0.6789 - val_accuracy: 0.8348
# Epoch 10/25
# 469/469 [==============================] - 2s 5ms/step - loss: 0.6733 - accuracy: 0.8343 - val_loss: 0.6373 - val_accuracy: 0.8477
# Epoch 11/25
# 469/469 [==============================] - 2s 5ms/step - loss: 0.6353 - accuracy: 0.8417 - val_loss: 0.6028 - val_accuracy: 0.8498
# Epoch 12/25
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6029 - accuracy: 0.8480 - val_loss: 0.5720 - val_accuracy: 0.8579
# Epoch 13/25
# 469/469 [==============================] - 2s 5ms/step - loss: 0.5749 - accuracy: 0.8537 - val_loss: 0.5457 - val_accuracy: 0.8631
# Epoch 14/25
# 469/469 [==============================] - 2s 5ms/step - loss: 0.5507 - accuracy: 0.8584 - val_loss: 0.5248 - val_accuracy: 0.8645
# Epoch 15/25
# 469/469 [==============================] - 2s 4ms/step - loss: 0.5296 - accuracy: 0.8630 - val_loss: 0.5035 - val_accuracy: 0.8711
# Epoch 16/25
# 469/469 [==============================] - 3s 7ms/step - loss: 0.5111 - accuracy: 0.8669 - val_loss: 0.4866 - val_accuracy: 0.8739
# Epoch 17/25
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4948 - accuracy: 0.8696 - val_loss: 0.4709 - val_accuracy: 0.8772
# Epoch 18/25
# 469/469 [==============================] - 2s 4ms/step - loss: 0.4803 - accuracy: 0.8731 - val_loss: 0.4571 - val_accuracy: 0.8798
# Epoch 19/25
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4672 - accuracy: 0.8762 - val_loss: 0.4452 - val_accuracy: 0.8825
# Epoch 20/25
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4556 - accuracy: 0.8785 - val_loss: 0.4344 - val_accuracy: 0.8832
# Epoch 21/25
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4452 - accuracy: 0.8806 - val_loss: 0.4247 - val_accuracy: 0.8863
# Epoch 22/25
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4356 - accuracy: 0.8817 - val_loss: 0.4157 - val_accuracy: 0.8900
# Epoch 23/25
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4270 - accuracy: 0.8838 - val_loss: 0.4073 - val_accuracy: 0.8902
# Epoch 24/25
# 469/469 [==============================] - 2s 4ms/step - loss: 0.4192 - accuracy: 0.8854 - val_loss: 0.4000 - val_accuracy: 0.8916
# Epoch 25/25
# 469/469 [==============================] - 2s 4ms/step - loss: 0.4120 - accuracy: 0.8870 - val_loss: 0.3931 - val_accuracy: 0.8933

# %%
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=128)
print(classification_report(testY.argmax(axis=1),
predictions.argmax(axis=1),
target_names=[str(x) for x in lb.classes_]))
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95       980
#            1       0.94      0.97      0.96      1135
#            2       0.89      0.86      0.88      1032
#            3       0.87      0.89      0.88      1010
#            4       0.89      0.91      0.90       982
#            5       0.85      0.80      0.83       892
#            6       0.91      0.92      0.92       958
#            7       0.91      0.89      0.90      1028
#            8       0.86      0.83      0.85       974
#            9       0.87      0.85      0.86      1009
#
#     accuracy                           0.89     10000
#    macro avg       0.89      0.89      0.89     10000
# weighted avg       0.89      0.89      0.89     10000
